# %%
# Model Training & Evaluation Notebook

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load model performance results
file_path = "../data/model_performance.csv"
df = pd.read_csv(file_path)

# Display results
print("Model Performance Results:")
print(df)

# Plot accuracy comparison
plt.figure(figsize=(8,5))
sns.barplot(x='Model', y='Accuracy', data=df)
plt.title("Model Accuracy Comparison")
plt.xticks(rotation=45)
plt.show()

# Plot Precision, Recall, and F1-Score
metrics = ['Precision', 'Recall', 'F1-Score']
for metric in metrics:
    plt.figure(figsize=(8,5))
    sns.barplot(x='Model', y=metric, data=df)
    plt.title(f"{metric} Comparison")
    plt.xticks(rotation=45)
    plt.show()

print("Model performance visualization completed.")
# Out:
# Model Performance Results:
#                     Model  Accuracy  Precision    Recall  F1-Score
# 0     Logistic Regression    0.9997   0.982456  0.965517  0.973913
# 1           Random Forest    1.0000   1.000000  1.000000  1.000000
# 2       Gradient Boosting    1.0000   1.000000  1.000000  1.000000
# 3  Support Vector Machine    0.9999   0.983051  1.000000  0.991453
# Model performance visualization completed.
